# %% [markdown]
# # The Layers
# In order to visualize the trained layers:
# Recreate the CNN model up until the layer you want to visualize.
# Copy weights from the trained model to the new model.
# Then use predict to transform an input image to the output at the desired layer.
# Plot the output image.

# %%
from matplotlib import pyplot as plt
# %matplotlib inline
import matplotlib.cm as cm
# Out:
# /usr/local/lib/python2.7/dist-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
import utils
reload(utils)
# Out:
# <module 'utils' from 'utils.py'>

# %% [markdown]
# ## Load the data

# %%
(X_train, Y_train), (X_test, Y_test) = utils.load_data()

# %% [markdown]
# ## Load the model

# %%
model_name = 'model-big-50'
model = utils.load_model(model_name)

# %% [markdown]
# ## Display test image

# %%
plt.figure(figsize=(6,6))
plt.axis('off')
plt.imshow(X_train[4].T)

# %% [markdown]
# ## Display each layer of the model

# %%
layer_num = 1
print "Layer: %d" % (layer_num)
out = utils.output_at_layer(X_train[:5], model_name, layer_num, verbose=True)
utils.visualize_output(out[4], figsize=(15,15))
# Out:
# Layer: 1
# ...
# (32, 3, 3, 3)
# Image dimensions: (5, 32, 30, 30)

# %%
layer_num = 2
print "Layer: %d" % (layer_num)
out = utils.output_at_layer(X_train[:5], model_name, layer_num, verbose=True)
utils.visualize_output(out[4], figsize=(15,15))
# Out:
# Layer: 2
# ...
# (32, 32, 3, 3)
# Image dimensions: (5, 32, 28, 28)

# %%
layer_num = 3
print "Layer: %d" % (layer_num)
out = utils.output_at_layer(X_train[:5], model_name, layer_num, verbose=True)
utils.visualize_output(out[4], figsize=(15,15))
# Out:
# Layer: 3
# ...
# Image dimensions: (5, 32, 14, 14)

# %%
layer_num = 4
print "Layer: %d" % (layer_num)
out = utils.output_at_layer(X_train[:5], model_name, layer_num, verbose=True)
utils.visualize_output(out[4], figsize=(15,15))
# Out:
# Layer: 4
# ...
# Image dimensions: (5, 32, 14, 14)

# %%
layer_num = 5
print "Layer: %d" % (layer_num)
out = utils.output_at_layer(X_train[:5], model_name, layer_num, verbose=True)
utils.visualize_output(out[4], figsize=(15,15))
# Out:
# Layer: 5
# ...
# (64, 32, 3, 3)
# Image dimensions: (5, 64, 12, 12)

# %%
layer_num = 6
print "Layer: %d" % (layer_num)
out = utils.output_at_layer(X_train[:5], model_name, layer_num, verbose=True)
utils.visualize_output(out[4], figsize=(15,15))
# Out:
# Layer: 6
# ...
# (64, 64, 3, 3)
# Image dimensions: (5, 64, 10, 10)

# %%
layer_num = 7
print "Layer: %d" % (layer_num)
out = utils.output_at_layer(X_train[:5], model_name, layer_num, verbose=True)
utils.visualize_output(out[4], figsize=(15,15))
# Out:
# Layer: 7
# ...
# Image dimensions: (5, 64, 5, 5)

# %%
layer_num = 8
print "Layer: %d" % (layer_num)
out = utils.output_at_layer(X_train[:5], model_name, layer_num, verbose=True)
utils.visualize_output(out[4], figsize=(15,15))
# Out:
# Layer: 8
# ...
# Image dimensions: (5, 64, 5, 5)
